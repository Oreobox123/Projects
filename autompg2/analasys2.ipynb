# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
                'acceleration', 'model_year', 'origin', 'car_name']

df = pd.read_csv('auto-mpg.data', delim_whitespace=True, names=column_names)
df['origin'] = df['origin'].map({1: 'USA', 2: 'Europe', 3: 'Asia'})
df['origin'].value_counts()
#df.size
# Out:
# C:\Users\meyus\AppData\Local\Temp\ipykernel_13872\2048649084.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('auto-mpg.data', delim_whitespace=True, names=column_names)
# origin
# USA       249
# Asia       79
# Europe     70
# Name: count, dtype: int64

# %%
int((df == '?').sum().sum())
# Out:
# 6

# %%
(df == '?').sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# dtype: int64

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#   origin                   car_name
# 0    USA  chevrolet chevelle malibu
# 1    USA          buick skylark 320
# 2    USA         plymouth satellite
# 3    USA              amc rebel sst
# 4    USA                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model_year  origin         car_name
# 393          82     USA  ford mustang gl
# 394          82  Europe        vw pickup
# 395          82     USA    dodge rampage
# 396          82     USA      ford ranger
# 397          82     USA       chevy s-10

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Length: 398, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model_year  origin                   car_name
# 0            70     USA  chevrolet chevelle malibu
# 1            70     USA          buick skylark 320
# 2            70     USA         plymouth satellite
# 3            70     USA              amc rebel sst
# 4            70     USA                ford torino
# ..          ...     ...                        ...
# 393          82     USA            ford mustang gl
# 394          82  Europe                  vw pickup
# 395          82     USA              dodge rampage
# 396          82     USA                ford ranger
# 397          82     USA                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# model_year        int64
# origin           object
# car_name         object
# dtype: object

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# dtype: int64

# %%
df['mpg'].mean()
# Out:
# np.float64(23.514572864321607)

# %%
df['cylinders'].value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
df.groupby('cylinders')['weight'].mean()
# Out:
# cylinders
# 3    2398.500000
# 4    2308.127451
# 5    3103.333333
# 6    3198.226190
# 8    4114.718447
# Name: weight, dtype: float64

# %%
df.sort_values(by='mpg', ascending=False).head(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0      65.00  2110.0          17.9
# 329  44.6          4          91.0      67.00  1850.0          13.8
# 325  44.3          4          90.0      48.00  2085.0          21.7
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 326  43.4          4          90.0      48.00  2335.0          23.7
#
#      model_year  origin              car_name origin_name
# 322          80    Asia             mazda glc         NaN
# 329          80    Asia   honda civic 1500 gl         NaN
# 325          80  Europe  vw rabbit c (diesel)         NaN
# 394          82  Europe             vw pickup         NaN
# 326          80  Europe    vw dasher (diesel)         NaN

# %%
df.groupby('model_year')['mpg'].mean()
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %%
df['car_name'].nunique()
# Out:
# 305

# %%
df.groupby('cylinders')['mpg'].mean()
# Out:
# cylinders
# 3    20.550000
# 4    29.286765
# 5    27.366667
# 6    19.985714
# 8    14.963107
# Name: mpg, dtype: float64

# %%
plt.scatter(df['weight'], df['mpg'], alpha=0.5)
plt.xlabel('Weight')
plt.ylabel('MPG')
plt.title('Weight vs MPG')
plt.grid(True)
plt.show()

# %%
df.loc[df['horsepower'].idxmax()]
# Out:
# mpg                   25.0
# cylinders                4
# displacement          98.0
# horsepower               ?
# weight              2046.0
# acceleration          19.0
# model_year              71
# origin                 USA
# car_name        ford pinto
# origin_name            NaN
# Name: 32, dtype: object

# %%
df.sort_values(by='mpg').head(5)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28   9.0          8         304.0      193.0  4732.0          18.5
# 25  10.0          8         360.0      215.0  4615.0          14.0
# 26  10.0          8         307.0      200.0  4376.0          15.0
# 67  11.0          8         429.0      208.0  4633.0          11.0
# 27  11.0          8         318.0      210.0  4382.0          13.5
#
#     model_year origin         car_name origin_name
# 28          70    USA         hi 1200d         NaN
# 25          70    USA        ford f250         NaN
# 26          70    USA        chevy c20         NaN
# 67          72    USA  mercury marquis         NaN
# 27          70    USA       dodge d200         NaN

# %%
df['model_year'].value_counts().sort_index()
# Out:
# model_year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# Name: count, dtype: int64

# %%
df.groupby('origin')['acceleration'].mean()
# Out:
# origin
# Asia      16.172152
# Europe    16.787143
# USA       15.033735
# Name: acceleration, dtype: float64

# %%
pd.crosstab(df['cylinders'], df['origin'])
# Out:
# origin     Asia  Europe  USA
# cylinders
# 3             4       0    0
# 4            69      63   72
# 5             0       3    0
# 6             6       4   74
# 8             0       0  103

# %%
df.loc[df['weight'].idxmax()]
# Out:
# mpg                            13.0
# cylinders                         8
# displacement                  400.0
# horsepower                    175.0
# weight                       5140.0
# acceleration                   12.0
# model_year                       71
# origin                          USA
# car_name        pontiac safari (sw)
# origin_name                     NaN
# Name: 44, dtype: object

# %%
df.groupby('model_year')['mpg'].mean().plot(kind='line', marker='o', figsize=(10, 6))
plt.title('MPG Trend by Model Year')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.grid(True)
plt.show()

# %%
df['car_name'].value_counts().head(15)
# Out:
# car_name
# ford pinto            6
# ford maverick         5
# amc matador           5
# toyota corolla        5
# amc hornet            4
# peugeot 504           4
# toyota corona         4
# amc gremlin           4
# chevrolet chevette    4
# chevrolet impala      4
# dodge colt            3
# ford gran torino      3
# pontiac catalina      3
# volkswagen dasher     3
# plymouth duster       3
# Name: count, dtype: int64

# %%
df.boxplot(column='mpg', by='cylinders', grid=False)
plt.title('MPG by Number of Cylinders')
plt.suptitle('')
plt.xlabel('Cylinders')
plt.ylabel('MPG')
plt.show()
